# %%
import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.layers import Bidirectional, LSTM, Reshape, GlobalAveragePooling1D, BatchNormalization, Dropout, Dense, Conv2D, MaxPooling2D, Activation, GRU
import pathlib
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pandas as pd
# Out:
# 2025-05-04 15:18:55.755414: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746371936.054288      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746371936.129943      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !pip install pyunpack
# !pip install patool
# Out:
# Collecting pyunpack
#   Downloading pyunpack-0.3-py2.py3-none-any.whl.metadata (863 bytes)
# Collecting easyprocess (from pyunpack)
#   Downloading EasyProcess-1.1-py3-none-any.whl.metadata (855 bytes)
# Collecting entrypoint2 (from pyunpack)
#   Downloading entrypoint2-1.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Downloading pyunpack-0.3-py2.py3-none-any.whl (4.1 kB)
# Downloading EasyProcess-1.1-py3-none-any.whl (8.7 kB)
# Downloading entrypoint2-1.1-py2.py3-none-any.whl (9.9 kB)
# Installing collected packages: entrypoint2, easyprocess, pyunpack
# Successfully installed easyprocess-1.1 entrypoint2-1.1 pyunpack-0.3
# Collecting patool
#   Downloading patool-4.0.1-py2.py3-none-any.whl.metadata (4.5 kB)
# Downloading patool-4.0.1-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.5/86.5 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: patool
# Successfully installed patool-4.0.1

# %%
import os
from pyunpack import Archive
import shutil
if not os.path.exists('/kaggle/working/train/'):
    os.makedirs('/kaggle/working/train/')
Archive('/kaggle/input/tensorflow-speech-recognition-challenge/train.7z').extractall('/kaggle/working/train/')

# %%
dataset_path = '/kaggle/working/train/train/audio'

data_dir = pathlib.Path(dataset_path)

commands = [cmd for cmd in tf.io.gfile.listdir(str(data_dir)) if cmd != '_background_noise_']
commands = np.array(commands)
print('Команды:', commands)
# Out:
# Команды: ['sheila' 'five' 'wow' 'go' 'two' 'nine' 'no' 'left' 'yes' 'dog' 'eight'
#  'house' 'marvin' 'happy' 'seven' 'down' 'up' 'right' 'bed' 'one' 'zero'
#  'cat' 'stop' 'tree' 'on' 'four' 'three' 'six' 'off' 'bird']

# %%
file_dict = defaultdict(list)
for command in commands:
    command_files = tf.io.gfile.glob(str(data_dir / command) + '/*')
    file_dict[command].extend(command_files)

# %%
train_files = []
val_files = []
test_files = []

for command, files in file_dict.items():
    files = tf.random.shuffle(files).numpy()
    
    train, temp = train_test_split(files, test_size=0.2, random_state=42)
    
    val, test = train_test_split(temp, test_size=0.5, random_state=42)
    
    train_files.extend(train)
    val_files.extend(val)
    test_files.extend(test)

train_files = tf.random.shuffle(train_files)
val_files = tf.random.shuffle(val_files)
test_files = tf.random.shuffle(test_files)

print('Общее количество записей:', len(train_files) + len(val_files) + len(test_files))
print('Размер обучающего набора:', len(train_files))
print('Размер набора валидации:', len(val_files))
print('Размер тестового набора:', len(test_files))
# Out:
# Общее количество записей: 64721
# Размер обучающего набора: 51764
# Размер набора валидации: 6471
# Размер тестового набора: 6486
# I0000 00:00:1746372045.048707      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1746372045.049417      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
def decode_audio(audio_binary):
  audio, _ = tf.audio.decode_wav(contents=audio_binary)
  return tf.squeeze(audio, axis=-1)

# %%
def get_label(file_path):
  parts = tf.strings.split(input=file_path,sep=os.path.sep)
  return parts[-2]

# %%
def get_waveform_and_label(file_path):
  label = get_label(file_path) 
  audio_binary = tf.io.read_file(file_path)
  waveform = decode_audio(audio_binary)
  return waveform, label

# %% [markdown]
# # SpectDataset

# %%
def get_spectrogram(waveform):
    input_len = 16000
    waveform = waveform[:input_len]
    
    zero_padding = tf.zeros([16000] - tf.shape(waveform), dtype=tf.float32)

    waveform = tf.cast(waveform, dtype=tf.float32)
    
    equal_length = tf.concat([waveform, zero_padding], 0)

    spectrogram = tf.signal.stft(equal_length, frame_length=255, frame_step=128)
    spectrogram = tf.abs(spectrogram)
    spectrogram = spectrogram[..., tf.newaxis]
    return spectrogram

# %%
def get_spectrogram_and_label_id(audio, label):
  spectrogram = get_spectrogram(audio)
  label_id = tf.argmax(label == commands)
  return spectrogram, label_id

# %%
def preprocess_dataset(files):
    files_ds = tf.data.Dataset.from_tensor_slices(files)
    
    output_ds = files_ds.map(map_func=get_waveform_and_label).map(map_func=get_spectrogram_and_label_id)
    
    return output_ds

# %%
spectrogram_ds = preprocess_dataset(train_files)
train_ds = spectrogram_ds
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)

# %%
batch_size = 128

train_ds = (train_ds
            .batch(batch_size)
            .cache()
            .prefetch(1)
           )

val_ds = (val_ds
          .batch(batch_size)
          .cache()
          .prefetch(1)
         )

# %%
for spectrogram, _ in spectrogram_ds.take(1):
  input_shape = spectrogram.shape
print('Размер входа', input_shape)

num_labels = len(commands)
# Out:
# Размер входа (124, 129, 1)

# %% [markdown]
# # Dense

# %%
model_spect_dense = models.Sequential([
    layers.Input(shape=(input_shape[0] * input_shape[1],)), 
    
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.3),
    
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    
    layers.Dense(128, activation='relu'),
    layers.Dense(num_labels)
])

model_spect_dense.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 512)                 │       8,190,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 30)                  │           3,870 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,358,558 (31.89 MB)
#  Trainable params: 8,358,558 (31.89 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_spect_dense.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
train_ds_dense = train_ds.map(lambda x, y: (tf.reshape(x, [-1, input_shape[0] * input_shape[1]]), y))
val_ds_dense = val_ds.map(lambda x, y: (tf.reshape(x, [-1, input_shape[0] * input_shape[1]]), y))
test_ds_dense = test_ds.map(lambda x, y: (tf.reshape(x, [-1, input_shape[0] * input_shape[1]]), y))

# %%
EPOCHS = 50
history = model_spect_dense.fit(
    train_ds_dense,
    validation_data=val_ds_dense,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True)
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746372049.617818     261 service.cc:148] XLA service 0x7c481800ee80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746372049.619878     261 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746372049.619912     261 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746372050.059133     261 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   9/405 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.0426 - loss: 3.8731
# I0000 00:00:1746372051.938880     261 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 34s 73ms/step - accuracy: 0.1787 - loss: 3.1055 - val_accuracy: 0.4686 - val_loss: 2.0271
# Epoch 2/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4208 - loss: 2.1163 - val_accuracy: 0.5747 - val_loss: 1.5653
# Epoch 3/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5211 - loss: 1.7116 - val_accuracy: 0.6270 - val_loss: 1.3445
# Epoch 4/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.5712 - loss: 1.4929 - val_accuracy: 0.6711 - val_loss: 1.2000
# Epoch 5/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6152 - loss: 1.3375 - val_accuracy: 0.6959 - val_loss: 1.0946
# Epoch 6/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6394 - loss: 1.2178 - val_accuracy: 0.7058 - val_loss: 1.0351
# Epoch 7/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6668 - loss: 1.1351 - val_accuracy: 0.7183 - val_loss: 0.9998
# Epoch 8/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6847 - loss: 1.0687 - val_accuracy: 0.7245 - val_loss: 0.9756
# Epoch 9/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6974 - loss: 1.0129 - val_accuracy: 0.7350 - val_loss: 0.9513
# Epoch 10/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7144 - loss: 0.9506 - val_accuracy: 0.7362 - val_loss: 0.9376
# Epoch 11/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7275 - loss: 0.9092 - val_accuracy: 0.7444 - val_loss: 0.8992
# Epoch 12/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7354 - loss: 0.8828 - val_accuracy: 0.7507 - val_loss: 0.8823
# Epoch 13/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7440 - loss: 0.8455 - val_accuracy: 0.7583 - val_loss: 0.8733
# Epoch 14/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7565 - loss: 0.8116 - val_accuracy: 0.7552 - val_loss: 0.8956
# Epoch 15/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7657 - loss: 0.7773 - val_accuracy: 0.7495 - val_loss: 0.8950
# Epoch 16/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7697 - loss: 0.7584 - val_accuracy: 0.7585 - val_loss: 0.8579
# Epoch 17/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7799 - loss: 0.7260 - val_accuracy: 0.7620 - val_loss: 0.8578
# Epoch 18/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7862 - loss: 0.7061 - val_accuracy: 0.7619 - val_loss: 0.8542
# Epoch 19/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7923 - loss: 0.6867 - val_accuracy: 0.7670 - val_loss: 0.8489
# Epoch 20/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7929 - loss: 0.6899 - val_accuracy: 0.7682 - val_loss: 0.8399
# Epoch 21/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7996 - loss: 0.6518 - val_accuracy: 0.7696 - val_loss: 0.8460
# Epoch 22/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8007 - loss: 0.6671 - val_accuracy: 0.7702 - val_loss: 0.8390
# Epoch 23/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8090 - loss: 0.6395 - val_accuracy: 0.7736 - val_loss: 0.8474
# Epoch 24/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8084 - loss: 0.6314 - val_accuracy: 0.7772 - val_loss: 0.8525
# Epoch 25/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8141 - loss: 0.6123 - val_accuracy: 0.7714 - val_loss: 0.8905
# Epoch 26/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8206 - loss: 0.6047 - val_accuracy: 0.7710 - val_loss: 0.8450

# %%
model_spect_dense.save("spect_dense.keras")

# %%
metrics = history.history

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.epoch, metrics['accuracy'], label='Train Accuracy')
plt.plot(history.epoch, metrics['val_accuracy'], label='Val Accuracy')
plt.title('Точность по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Точность')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.epoch, metrics['loss'], label='Train Loss')
plt.plot(history.epoch, metrics['val_loss'], label='Val Loss')
plt.title('Потеря по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Потеря')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("training_metrics_spect_dense.png", dpi=300)
plt.show()

# %%
test_audio = []
test_labels = []

for audio, label in test_ds_dense:
  test_audio.append(audio.numpy())
  test_labels.append(label.numpy())

test_audio = np.array(test_audio)
test_labels = np.array(test_labels)

test_audio = np.squeeze(test_audio, axis=1)

# %%
y_pred = np.argmax(model_spect_dense.predict(test_audio), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Точность на тестовом наборе: {test_acc:.0%}')
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Точность на тестовом наборе: 78%

# %%
report = classification_report(y_true, y_pred, target_names=commands, digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       sheila     0.8941    0.8736    0.8837       174
#         five     0.7106    0.7076    0.7091       236
#          wow     0.7104    0.7429    0.7263       175
#           go     0.6962    0.6933    0.6947       238
#          two     0.7412    0.7941    0.7667       238
#         nine     0.6438    0.7932    0.7108       237
#           no     0.6762    0.6933    0.6846       238
#         left     0.8170    0.7754    0.7957       236
#          yes     0.9391    0.7773    0.8506       238
#          dog     0.6755    0.5829    0.6258       175
#        eight     0.7795    0.8686    0.8216       236
#        house     0.9268    0.8686    0.8968       175
#       marvin     0.9452    0.7886    0.8598       175
#        happy     0.9390    0.8800    0.9086       175
#        seven     0.8722    0.8319    0.8516       238
#         down     0.7108    0.7500    0.7299       236
#           up     0.7689    0.8529    0.8088       238
#        right     0.8517    0.7511    0.7982       237
#          bed     0.6556    0.6860    0.6705       172
#          one     0.8000    0.7257    0.7611       237
#         zero     0.8940    0.8151    0.8527       238
#          cat     0.7571    0.7701    0.7635       174
#         stop     0.9037    0.8277    0.8640       238
#         tree     0.6667    0.6897    0.6780       174
#           on     0.6929    0.7046    0.6987       237
#         four     0.7391    0.8571    0.7938       238
#        three     0.7025    0.7203    0.7113       236
#          six     0.8397    0.9283    0.8818       237
#          off     0.7804    0.7076    0.7422       236
#         bird     0.7895    0.8621    0.8242       174
#
#     accuracy                         0.7777      6486
#    macro avg     0.7840    0.7773    0.7788      6486
# weighted avg     0.7830    0.7777    0.7785      6486

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 7))

sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g',
            cmap='Blues')
plt.xlabel('Предсказание')
plt.ylabel('Метка')
plt.savefig("conf_matrix_spect_dense.png", dpi=300)
plt.show()

# %% [markdown]
# # CNN

# %%
norm_layer = layers.Normalization()

norm_layer.adapt(data=spectrogram_ds.map(map_func=lambda spec, label: spec))

# %%
model_spect_cnn = models.Sequential([
    layers.Input(shape=input_shape),
    layers.Resizing(32, 32),
    norm_layer,
    
    layers.Conv2D(32, 3),
    layers.Activation('relu'),
    
    layers.Conv2D(64, 3),
    layers.Activation('relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),

    layers.Conv2D(128, 3),
    layers.Activation('relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),

50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9109 - loss: 0.2939 - val_accuracy: 0.9277 - val_loss: 0.2727
# Epoch 30/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9158 - loss: 0.2879 - val_accuracy: 0.9272 - val_loss: 0.2716
# Epoch 31/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9148 - loss: 0.2808 - val_accuracy: 0.9280 - val_loss: 0.2846
# Epoch 32/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9170 - loss: 0.2828 - val_accuracy: 0.9291 - val_loss: 0.2751
# Epoch 33/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9196 - loss: 0.2679 - val_accuracy: 0.9269 - val_loss: 0.2787
# Epoch 34/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9179 - loss: 0.2724 - val_accuracy: 0.9317 - val_loss: 0.2758
# Epoch 35/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9207 - loss: 0.2677 - val_accuracy: 0.9283 - val_loss: 0.2801
# Epoch 36/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9203 - loss: 0.2680 - val_accuracy: 0.9275 - val_loss: 0.2798

# %%
model_spect_cnn.save("spect_cnn.keras")

# %%
metrics = history.history

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.epoch, metrics['accuracy'], label='Train Accuracy')
plt.plot(history.epoch, metrics['val_accuracy'], label='Val Accuracy')
plt.title('Точность по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Точность')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.epoch, metrics['loss'], label='Train Loss')
plt.plot(history.epoch, metrics['val_loss'], label='Val Loss')
plt.title('Потеря по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Потеря')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("training_metrics_spect_cnn.png", dpi=300)
plt.show()

# %%
test_audio = []
test_labels = []

for audio, label in test_ds:
  test_audio.append(audio.numpy())
  test_labels.append(label.numpy())

test_audio = np.array(test_audio)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model_spect_cnn.predict(test_audio), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Точность на тестовом наборе: {test_acc:.0%}')
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# Точность на тестовом наборе: 93%

# %%
report = classification_report(y_true, y_pred, target_names=commands, digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       sheila     0.9881    0.9540    0.9708       174
#         five     0.9227    0.9110    0.9168       236
#          wow     0.9937    0.9029    0.9461       175
#           go     0.7852    0.8908    0.8346       238
#          two     0.9741    0.9496    0.9617       238
#         nine     0.9397    0.9198    0.9296       237
#           no     0.9091    0.9244    0.9167       238
#         left     0.9303    0.9619    0.9458       236
#          yes     0.9786    0.9622    0.9703       238
#          dog     0.9461    0.9029    0.9240       175
#        eight     0.9274    0.9746    0.9504       236
#        house     0.9706    0.9429    0.9565       175
#       marvin     1.0000    0.9257    0.9614       175
#        happy     0.9830    0.9886    0.9858       175
#        seven     0.9619    0.9538    0.9578       238
#         down     0.9356    0.9237    0.9296       236
#           up     0.7839    0.8992    0.8376       238
#        right     0.9612    0.9409    0.9510       237
#          bed     0.9398    0.9070    0.9231       172
#          one     0.9682    0.8987    0.9322       237
#         zero     0.9694    0.9328    0.9507       238
#          cat     0.9385    0.9655    0.9518       174
#         stop     0.9407    0.9328    0.9367       238
#         tree     0.9345    0.9023    0.9181       174
#           on     0.8911    0.9325    0.9113       237
#         four     0.9600    0.9076    0.9330       238
#        three     0.9091    0.9322    0.9205       236
#          six     0.9538    0.9578    0.9558       237
#          off     0.9012    0.9280    0.9144       236
#         bird     0.9171    0.9540    0.9352       174
#
#     accuracy                         0.9325      6486
#    macro avg     0.9372    0.9327    0.9343      6486
# weighted avg     0.9348    0.9325    0.9331      6486

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 7))

sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g',
            cmap='Blues')
plt.xlabel('Предсказание')
plt.ylabel('Метка')
plt.savefig("conf_matrix_spect_cnn.png", dpi=300)
plt.show()

# %% [markdown]
# # TCN

# %%
def get_spectrogram_and_label_id(audio, label):
    spectrogram = get_spectrogram(audio)
    spectrogram = tf.squeeze(spectrogram, axis=-1)
    label_id = tf.argmax(label == commands)
    return spectrogram, label_id

# %%
spectrogram_ds = preprocess_dataset(train_files)
train_ds = spectrogram_ds
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)

# %%
for spectrogram, _ in spectrogram_ds.take(1):
    input_shape = spectrogram.shape
print('Новый размер входа:', input_shape)
# Out:
# Новый размер входа: (124, 129)

# %%
norm_layer = layers.Normalization()
norm_layer.adapt(spectrogram_ds.map(lambda x, y: x))

# %%
model_spect_tcn = models.Sequential([
    layers.Input(shape=input_shape),
    norm_layer,
    
    layers.Conv1D(64, kernel_size=3, dilation_rate=1, padding='causal', activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    
    layers.Conv1D(128, kernel_size=3, dilation_rate=2, padding='causal', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling1D(pool_size=2),
    layers.Dropout(0.4),
    
    layers.Conv1D(256, kernel_size=3, dilation_rate=4, padding='causal', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling1D(pool_size=2),
    layers.Dropout(0.5),
    
    layers.GlobalAveragePooling1D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels)
])

model_spect_tcn.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization)      │ (None, 124, 129)            │             259 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d (Conv1D)                      │ (None, 124, 64)             │          24,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 124, 64)             │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 124, 64)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 124, 128)            │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 124, 128)            │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 62, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 62, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_2 (Conv1D)                    │ (None, 62, 256)             │          98,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 62, 256)             │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 31, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 31, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling1d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling1D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 30)                  │           7,710 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 223,649 (873.63 KB)
#  Trainable params: 222,494 (869.12 KB)
#  Non-trainable params: 1,155 (4.52 KB)

# %%
model_spect_tcn.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
EPOCHS = 50
history_tcn = model_spect_tcn.fit(
    train_ds.batch(batch_size).cache().prefetch(1),
    validation_data=val_ds.batch(batch_size).cache().prefetch(1),
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(patience=6, restore_best_weights=True)
)
# Out:
# Epoch 1/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - accuracy: 0.2562 - loss: 2.6148 - val_accuracy: 0.6946 - val_loss: 1.0931
# Epoch 2/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6979 - loss: 1.0395 - val_accuracy: 0.8277 - val_loss: 0.6063
# Epoch 3/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7893 - loss: 0.7067 - val_accuracy: 0.8691 - val_loss: 0.4697
# Epoch 4/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8285 - loss: 0.5792 - val_accuracy: 0.8883 - val_loss: 0.4062
# Epoch 5/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8489 - loss: 0.5162 - val_accuracy: 0.9013 - val_loss: 0.3609
# Epoch 6/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8625 - loss: 0.4662 - val_accuracy: 0.8988 - val_loss: 0.3575
# Epoch 7/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8724 - loss: 0.4382 - val_accuracy: 0.9125 - val_loss: 0.3103
# Epoch 8/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8791 - loss: 0.4131 - val_accuracy: 0.9221 - val_loss: 0.2868
# Epoch 9/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8830 - loss: 0.3942 - val_accuracy: 0.9213 - val_loss: 0.2808
# Epoch 10/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8905 - loss: 0.3652 - val_accuracy: 0.9235 - val_loss: 0.2692
# Epoch 11/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8922 - loss: 0.3587 - val_accuracy: 0.9326 - val_loss: 0.2393
# Epoch 12/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8959 - loss: 0.3497 - val_accuracy: 0.9309 - val_loss: 0.2504
# Epoch 13/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8977 - loss: 0.3418 - val_accuracy: 0.9314 - val_loss: 0.2452
# Epoch 14/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8999 - loss: 0.3333 - val_accuracy: 0.9343 - val_loss: 0.2381
# Epoch 15/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9065 - loss: 0.3179 - val_accuracy: 0.9363 - val_loss: 0.2293
# Epoch 16/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9065 - loss: 0.3097 - val_accuracy: 0.9373 - val_loss: 0.2352
# Epoch 17/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9071 - loss: 0.3109 - val_accuracy: 0.9339 - val_loss: 0.2408
# Epoch 18/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9113 - loss: 0.2966 - val_accuracy: 0.9386 - val_loss: 0.2185
# Epoch 19/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9101 - loss: 0.2956 - val_accuracy: 0.9391 - val_loss: 0.2181
# Epoch 20/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9123 - loss: 0.2945 - val_accuracy: 0.9411 - val_loss: 0.2169
# Epoch 21/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9151 - loss: 0.2848 - val_accuracy: 0.8878 - val_loss: 0.4736
# Epoch 22/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9156 - loss: 0.2797 - val_accuracy: 0.9354 - val_loss: 0.2463
# Epoch 23/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9185 - loss: 0.2726 - val_accuracy: 0.9419 - val_loss: 0.2070
# Epoch 24/50
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.


# %%
report = classification_report(y_true, y_pred, target_names=commands, digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       sheila     0.9766    0.9598    0.9681       174
#         five     0.9362    0.9322    0.9342       236
#          wow     0.9598    0.9543    0.9570       175
#           go     0.9520    0.9160    0.9336       238
#          two     0.9580    0.9580    0.9580       238
#         nine     0.9417    0.9536    0.9476       237
#           no     0.9407    0.9328    0.9367       238
#         left     0.9742    0.9619    0.9680       236
#          yes     0.9831    0.9790    0.9811       238
#          dog     0.9598    0.9543    0.9570       175
#        eight     0.9465    0.9746    0.9603       236
#        house     0.9714    0.9714    0.9714       175
#       marvin     0.9882    0.9543    0.9709       175
#        happy     0.9831    0.9943    0.9886       175
#        seven     0.9870    0.9580    0.9723       238
#         down     0.9617    0.9576    0.9597       236
#           up     0.8872    0.9580    0.9212       238
#        right     0.8235    0.9451    0.8802       237
#          bed     0.9310    0.9419    0.9364       172
#          one     0.9300    0.9536    0.9417       237
#         zero     0.9867    0.9328    0.9590       238
#          cat     0.9884    0.9770    0.9827       174
#         stop     0.9868    0.9454    0.9657       238
#         tree     0.9034    0.9138    0.9086       174
#           on     0.9370    0.9409    0.9389       237
#         four     0.9786    0.9622    0.9703       238
#        three     0.9142    0.9025    0.9083       236
#          six     0.9831    0.9789    0.9810       237
#          off     0.9386    0.9068    0.9224       236
#         bird     0.9422    0.9368    0.9395       174
#
#     accuracy                         0.9497      6486
#    macro avg     0.9517    0.9503    0.9507      6486
# weighted avg     0.9509    0.9497    0.9500      6486

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 7))

sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g',
            cmap='Blues')
plt.xlabel('Предсказание')
plt.ylabel('Метка')
plt.savefig("conf_matrix_spect_tcn.png", dpi=300)
plt.show()

# %% [markdown]
# # CRNN

# %%
def get_spectrogram_and_label_id(audio, label):
    spectrogram = get_spectrogram(audio)
    label_id = tf.argmax(label == commands)
    return spectrogram, label_id

# %%
spectrogram_ds = preprocess_dataset(train_files)
train_ds = spectrogram_ds
val_ds = preprocess_dataset(val_files)
test_ds = preprocess_dataset(test_files)

# %%
for spectrogram, _ in spectrogram_ds.take(1):
    input_shape = spectrogram.shape
print('Новый размер входа:', input_shape)
# Out:
# Новый размер входа: (124, 129, 1)

# %%
norm_layer = layers.Normalization()
norm_layer.adapt(spectrogram_ds.map(lambda x, y: x))

# %%
model_spect_crnn = models.Sequential([
    layers.Input(shape=input_shape),
    norm_layer,
    
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),
    Dropout(0.2),
    
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),
    Dropout(0.3),
    
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),
    Dropout(0.4),
    
    layers.Reshape((-1, 128)),
    
    Bidirectional(LSTM(64, return_sequences=True)),
    Dropout(0.5),
    Bidirectional(LSTM(32)),
    Dropout(0.5),
    
    Dense(128, activation='relu'),
    Dropout(0.4),
    Dense(num_labels)
])

model_spect_crnn.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization_2 (Normalization)      │ (None, 124, 129, 1)         │               3 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 124, 129, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 62, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 62, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 62, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 31, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 31, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 31, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 15, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 15, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 240, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 240, 128)            │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 240, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 64)                  │          41,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 30)                  │           3,870 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 244,897 (956.63 KB)
#  Trainable params: 244,894 (956.62 KB)
#  Non-trainable params: 3 (16.00 B)

# %%
model_spect_crnn.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
EPOCHS = 150
history_crnn = model_spect_crnn.fit(
    train_ds.batch(batch_size).cache().prefetch(1),
    validation_data=val_ds.batch(batch_size).cache().prefetch(1),
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
)
# Out:
# Epoch 1/150
# E0000 00:00:1746372983.313654      31 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_3_1/dropout_10_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 67s 141ms/step - accuracy: 0.0379 - loss: 3.3962 - val_accuracy: 0.0620 - val_loss: 3.2720
# Epoch 2/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 52s 128ms/step - accuracy: 0.0736 - loss: 3.1840 - val_accuracy: 0.1012 - val_loss: 3.0213
# Epoch 3/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 54s 133ms/step - accuracy: 0.0940 - loss: 3.0202 - val_accuracy: 0.1388 - val_loss: 2.8157
# Epoch 4/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━
150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.8824 - loss: 0.4185 - val_accuracy: 0.9125 - val_loss: 0.3139
# Epoch 35/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.8882 - loss: 0.4029 - val_accuracy: 0.9187 - val_loss: 0.2881
# Epoch 36/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 135ms/step - accuracy: 0.8914 - loss: 0.3954 - val_accuracy: 0.9277 - val_loss: 0.2631
# Epoch 37/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.8915 - loss: 0.3893 - val_accuracy: 0.9272 - val_loss: 0.2628
# Epoch 38/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.8940 - loss: 0.3813 - val_accuracy: 0.9294 - val_loss: 0.2582
# Epoch 39/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.8961 - loss: 0.3696 - val_accuracy: 0.9343 - val_loss: 0.2512
# Epoch 40/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.8989 - loss: 0.3536 - val_accuracy: 0.9317 - val_loss: 0.2635
# Epoch 41/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.9006 - loss: 0.3569 - val_accuracy: 0.9343 - val_loss: 0.2419
# Epoch 42/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.9045 - loss: 0.3454 - val_accuracy: 0.9325 - val_loss: 0.2509
# Epoch 43/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.9063 - loss: 0.3416 - val_accuracy: 0.9312 - val_loss: 0.2551
# Epoch 44/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.9097 - loss: 0.3319 - val_accuracy: 0.9368 - val_loss: 0.2500
# Epoch 45/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.9089 - loss: 0.3307 - val_accuracy: 0.9362 - val_loss: 0.2423
# Epoch 46/150
# 405/405 ━━━━━━━━━━━━━━━━━━━━ 55s 136ms/step - accuracy: 0.9119 - loss: 0.3167 - val_accuracy: 0.9292 - val_loss: 0.2645

# %%
model_spect_crnn.save("spect_crnn.keras")

# %%
metrics = history_crnn.history

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history_crnn.epoch, metrics['accuracy'], label='Train Accuracy')
plt.plot(history_crnn.epoch, metrics['val_accuracy'], label='Val Accuracy')
plt.title('Точность по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Точность')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history_crnn.epoch, metrics['loss'], label='Train Loss')
plt.plot(history_crnn.epoch, metrics['val_loss'], label='Val Loss')
plt.title('Потеря по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Потеря')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("training_metrics_spect_crnn.png", dpi=300)
plt.show()

# %%
test_audio = []
test_labels = []

for audio, label in test_ds:
  test_audio.append(audio.numpy())
  test_labels.append(label.numpy())

test_audio = np.array(test_audio)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model_spect_crnn.predict(test_audio), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Точность на тестовом наборе: {test_acc:.0%}')
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step
# Точность на тестовом наборе: 94%

# %%
report = classification_report(y_true, y_pred, target_names=commands, digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       sheila     0.9766    0.9598    0.9681       174
#         five     0.9083    0.9237    0.9160       236
#          wow     0.9824    0.9543    0.9681       175
#           go     0.8755    0.8866    0.8810       238
#          two     0.9738    0.9370    0.9550       238
#         nine     0.9289    0.9367    0.9328       237
#           no     0.9300    0.9496    0.9397       238
#         left     0.8960    0.9492    0.9218       236
#          yes     0.9320    0.9790    0.9549       238
#          dog     0.9451    0.8857    0.9145       175
#        eight     0.7889    0.9661    0.8686       236
#        house     0.9600    0.9600    0.9600       175
#       marvin     0.9766    0.9543    0.9653       175
#        happy     0.9830    0.9886    0.9858       175
#        seven     0.9701    0.9538    0.9619       238
#         down     0.9205    0.9322    0.9263       236
#           up     0.9146    0.9454    0.9298       238
#        right     0.9781    0.9409    0.9591       237
#          bed     0.9521    0.9244    0.9381       172
#          one     0.9380    0.9578    0.9478       237
#         zero     0.9696    0.9370    0.9530       238
#          cat     0.9693    0.9080    0.9377       174
#         stop     0.9696    0.9370    0.9530       238
#         tree     0.9128    0.9023    0.9075       174
#           on     0.9813    0.8861    0.9313       237
#         four     0.9620    0.9580    0.9600       238
#        three     0.9129    0.9322    0.9224       236
#          six     0.9463    0.9662    0.9562       237
#          off     0.9348    0.9110    0.9227       236
#         bird     0.9755    0.9138    0.9436       174
#
#     accuracy                         0.9382      6486
#    macro avg     0.9422    0.9379    0.9394      6486
# weighted avg     0.9402    0.9382    0.9385      6486

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 7))

sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g',
            cmap='Blues')
plt.xlabel('Предсказание')
plt.ylabel('Метка')
plt.savefig("conf_matrix_spect_crnn.png", dpi=300)
plt.show()
