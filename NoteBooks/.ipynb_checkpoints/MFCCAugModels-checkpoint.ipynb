# %%
import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.layers import Bidirectional, LSTM, Reshape, GlobalAveragePooling1D, BatchNormalization, Dropout, Dense, Conv2D, MaxPooling2D, Activation, GRU
import pathlib
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pandas as pd
# Out:
# 2025-05-09 18:31:23.559627: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746815483.800410      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746815483.868385      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !pip install pyunpack
# !pip install patool
# Out:
# Collecting pyunpack
#   Downloading pyunpack-0.3-py2.py3-none-any.whl.metadata (863 bytes)
# Collecting easyprocess (from pyunpack)
#   Downloading EasyProcess-1.1-py3-none-any.whl.metadata (855 bytes)
# Collecting entrypoint2 (from pyunpack)
#   Downloading entrypoint2-1.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Downloading pyunpack-0.3-py2.py3-none-any.whl (4.1 kB)
# Downloading EasyProcess-1.1-py3-none-any.whl (8.7 kB)
# Downloading entrypoint2-1.1-py2.py3-none-any.whl (9.9 kB)
# Installing collected packages: entrypoint2, easyprocess, pyunpack
# Successfully installed easyprocess-1.1 entrypoint2-1.1 pyunpack-0.3
# Collecting patool
#   Downloading patool-4.0.1-py2.py3-none-any.whl.metadata (4.5 kB)
# Downloading patool-4.0.1-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.5/86.5 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: patool
# Successfully installed patool-4.0.1

# %%
SAMPLE_RATE = 16000

try:
    import tensorflow_io as tfio
    _HAS_TFIO = True
except ImportError:
    _HAS_TFIO = False
# Out:
# /usr/local/lib/python3.11/dist-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/usr/local/lib/python3.11/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/usr/local/lib/python3.11/dist-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl8str_util8EndsWithESt17basic_string_viewIcSt11char_traitsIcEES4_']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /usr/local/lib/python3.11/dist-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/usr/local/lib/python3.11/dist-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/usr/local/lib/python3.11/dist-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZN3tsl8str_util9LowercaseB5cxx11ESt17basic_string_viewIcSt11char_traitsIcEE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
import os
from pyunpack import Archive
import shutil
if not os.path.exists('/kaggle/working/train/'):
    os.makedirs('/kaggle/working/train/')
Archive('/kaggle/input/tensorflow-speech-recognition-challenge/train.7z').extractall('/kaggle/working/train/')

# %%
dataset_path = '/kaggle/working/train/train/audio'

# Преобразуем путь в объект pathlib.Path для удобной работы с файловой системой
data_dir = pathlib.Path(dataset_path)

commands = [cmd for cmd in tf.io.gfile.listdir(str(data_dir)) if cmd != '_background_noise_']
commands = np.array(commands)
print('Команды:', commands)
# Out:
# Команды: ['cat' 'yes' 'one' 'off' 'on' 'wow' 'stop' 'dog' 'four' 'two' 'tree'
#  'eight' 'happy' 'five' 'no' 'three' 'marvin' 'bed' 'house' 'zero' 'go'
#  'seven' 'left' 'sheila' 'bird' 'down' 'six' 'up' 'nine' 'right']

# %%
import os
import shutil
import numpy as np
from sklearn.model_selection import train_test_split

def create_stratified_split(source_dir, target_dir, test_val_ratio=0.2, random_seed=42):
    os.makedirs(os.path.join(target_dir, 'train'), exist_ok=True)
    os.makedirs(os.path.join(target_dir, 'val'), exist_ok=True)
    os.makedirs(os.path.join(target_dir, 'test'), exist_ok=True)
    
    for class_name in os.listdir(source_dir):
        class_dir = os.path.join(source_dir, class_name)
        if not os.path.isdir(class_dir) or class_name == '_background_noise_':
            continue
            
        all_files = [f for f in os.listdir(class_dir) if f.endswith('.wav')]
        if not all_files:
            continue
            
        train_files, temp_files = train_test_split(
            all_files,
            test_size=test_val_ratio,
            random_state=random_seed
        )
        val_files, test_files = train_test_split(
            temp_files,
            test_size=0.5,
            random_state=random_seed
        )
        
        for folder in ['train', 'val', 'test']:
            os.makedirs(os.path.join(target_dir, folder, class_name), exist_ok=True)
        
        def copy_files(files, target_folder):
            for f in files:
                src = os.path.join(class_dir, f)
                dst = os.path.join(target_dir, target_folder, class_name, f)
                shutil.copy2(src, dst)
        
        copy_files(train_files, 'train')
        copy_files(val_files, 'val')
        copy_files(test_files, 'test')
        
        print(f'Class {class_name}: {len(train_files)} train, {len(val_files)} val, {len(test_files)} test')

# %%
SOURCE_DIR = '/kaggle/working/train/train/audio'
TARGET_DIR = '/kaggle/working/split_data'
    
create_stratified_split(SOURCE_DIR, TARGET_DIR)
    
total_train = sum(len(files) for _, _, files in os.walk(os.path.join(TARGET_DIR, 'train')))
total_val = sum(len(files) for _, _, files in os.walk(os.path.join(TARGET_DIR, 'val')))
total_test = sum(len(files) for _, _, files in os.walk(os.path.join(TARGET_DIR, 'test')))
    
print('\nИтоговые размеры:')
print(f'Train: {total_train} файлов')
print(f'Val: {total_val} файлов')
print(f'Test: {total_test} файлов')
# Out:
# Class cat: 1386 train, 173 val, 174 test
# Class yes: 1901 train, 238 val, 238 test
# Class one: 1896 train, 237 val, 237 test
# Class off: 1885 train, 236 val, 236 test
# Class on: 1893 train, 237 val, 237 test
# Class wow: 1396 train, 174 val, 175 test
# Class stop: 1904 train, 238 val, 238 test
# Class dog: 1396 train, 175 val, 175 test
# Class four: 1897 train, 237 val, 238 test
# Class two: 1898 train, 237 val, 238 test
# Class tree: 1386 train, 173 val, 174 test
# Class eight: 1881 train, 235 val, 236 test
# Class happy: 1393 train, 174 val, 175 test
# Class five: 1885 train, 236 val, 236 test
# Class no: 1900 train, 237 val, 238 test
# Class three: 1884 train, 236 val, 236 test
# Class marvin: 1396 train, 175 val, 175 test
# Class bed: 1370 train, 171 val, 172 test
# Class house: 1400 train, 175 val, 175 test
# Class zero: 1900 train, 238 val, 238 test
# Class go: 1897 train, 237 val, 238 test
# Class seven: 1901 train, 238 val, 238 test
# Class left: 1882 train, 235 val, 236 test
# Class sheila: 1387 train, 173 val, 174 test
# Class bird: 1384 train, 173 val, 174 test
# Class down: 1887 train, 236 val, 236 test
# Class six: 1895 train, 237 val, 237 test
# Class up: 1900 train, 237 val, 238 test
# Class nine: 1891 train, 236 val, 237 test
# Class right: 1893 train, 237 val, 237 test
#
# Итоговые размеры:
# Train: 51764 файлов
# Val: 6471 файлов
# Test: 6486 файлов

# %%
def add_random_noise(waveform, max_noise_level=0.02):
    noise_level = tf.random.uniform(shape=[], maxval=max_noise_level)
    noise = tf.random.normal(shape=tf.shape(waveform), mean=0.0, stddev=noise_level)
    return waveform + noise

# %%
def random_volume(waveform, min_factor=0.5, max_factor=1.5):
    factor = tf.random.uniform(shape=[], minval=min_factor, maxval=max_factor)
    return waveform * factor

# %%
def time_shift(waveform, shift_max=0.2):
    shift = int(tf.random.uniform([], -shift_max, shift_max) * SAMPLE_RATE)
    return tf.roll(waveform, shift, axis=0)

# %%
def stretch_time(waveform, min_rate=0.8, max_rate=1.25):
    rate = tf.random.uniform([], minval=min_rate, maxval=max_rate)

    def _np_stretch(wav_np, rate_np):
        import numpy as np
        orig_len = wav_np.shape[0]
        target_len = int(orig_len * float(rate_np))
        if target_len < 2:
            return wav_np
        x_old = np.linspace(0, orig_len - 1, orig_len)
        x_new = np.linspace(0, orig_len - 1, target_len)
        stretched = np.interp(x_new, x_old, wav_np).astype(np.float32)
        if stretched.shape[0] < orig_len:
            pad = np.zeros(orig_len - stretched.shape[0], dtype=np.float32)
            stretched = np.concatenate([stretched, pad])
        else:
            stretched = stretched[:orig_len]
        return stretched

    stretched = tf.numpy_function(_np_stretch, [waveform, rate], tf.float32)
    stretched.set_shape(waveform.shape)
    return stretched

# %%
def decode_audio(audio_binary):
  audio, _ = tf.audio.decode_wav(contents=audio_binary)
  return tf.squeeze(audio, axis=-1)

# %%
import os
import tensorflow as tf
from tqdm import tqdm

def add_augmented_files(dataset_dir):
    for class_name in tqdm(os.listdir(dataset_dir), desc='Processing classes'):
        class_dir = os.path.join(dataset_dir, class_name)
        if not os.path.isdir(class_dir) or class_name == '_background_noise_':
            continue

        existing_files = set(os.listdir(class_dir))

        for filename in os.listdir(class_dir):
            if filename.startswith('aug_'):
                continue

            input_path = os.path.join(class_dir, filename)
            aug_filename = f'aug_{filename}'

            if aug_filename not in existing_files:
                audio_binary = tf.io.read_file(input_path)
                waveform = decode_audio(audio_binary)

                augmented = add_random_noise(
                    random_volume(
                        time_shift(
                            stretch_time(waveform)
                        )
                    )
                )

                aug_path = os.path.join(class_dir, aug_filename)
                wav_data = tf.audio.encode_wav(augmented[:, tf.newaxis], SAMPLE_RATE)
                tf.io.write_file(aug_path, wav_data)


dataset_path = '/kaggle/working/split_data/train'

add_augmented_files(dataset_path)
# Out:
# Processing classes:   0%|          | 0/30 [00:00<?, ?it/s]2025-05-09 18:33:42.986139: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Processing classes: 100%|██████████| 30/30 [04:42<00:00,  9.42s/it]

# %%
import tensorflow as tf
import pathlib

def load_split_dataset(base_dir):
    base = pathlib.Path(base_dir)

    train_files = [str(p) for p in base.joinpath('train').rglob('*.wav')]
    val_files   = [str(p) for p in base.joinpath('val').rglob('*.wav')]
    test_files  = [str(p) for p in base.joinpath('test').rglob('*.wav')]

    return train_files, val_files, test_files

# %%
TARGET_DIR = '/kaggle/working/split_data'
train_files, val_files, test_files = load_split_dataset(TARGET_DIR)

print(f'Train files: {len(list(train_files))}')
print(f'Val files: {len(list(val_files))}')
print(f'Test files: {len(list(test_files))}')
# Out:
# Train files: 103528
# Val files: 6471
# Test files: 6486

# %%
def get_label(file_path):
  parts = tf.strings.split(input=file_path,sep=os.path.sep)
  return parts[-2]

# %%
def get_waveform_and_label(file_path):
  label = get_label(file_path) 
  audio_binary = tf.io.read_file(file_path)
  waveform = decode_audio(audio_binary)
  return waveform, label

# %% [markdown]
# # MFCCDataset

# %%
def get_mfcc(waveform):
    input_len = 16000
    waveform = waveform[:input_len]
    zero_padding = tf.zeros([16000] - tf.shape(waveform), dtype=tf.float32)
    waveform = tf.concat([waveform, zero_padding], 0)
    
    stft = tf.signal.stft(waveform, frame_length=400, frame_step=160)
    spectrogram = tf.abs(stft)
    
    num_mel_bins = 80
    linear_to_mel_weight_matrix = tf.signal.linear_to_mel_weight_matrix(
        num_mel_bins=num_mel_bins,
        num_spectrogram_bins=spectrogram.shape[-1],
        sample_rate=16000,
        lower_edge_hertz=80.0,
        upper_edge_hertz=7600.0
    )
    
    mel_spectrogram = tf.tensordot(spectrogram, linear_to_mel_weight_matrix, 1)
    mel_spectrogram.set_shape(spectrogram.shape[:-1].concatenate(linear_to_mel_weight_matrix.shape[-1:]))
    
    log_mel_spectrogram = tf.math.log(mel_spectrogram + 1e-6)
    
    num_mfcc = 13
    mfcc = tf.signal.mfccs_from_log_mel_spectrograms(log_mel_spectrogram)[..., :num_mfcc]
    
    mfcc = mfcc[..., tf.newaxis]
    return mfcc

# %%
def get_mfcc_and_label_id(audio, label):
    mfcc_features = get_mfcc(audio)
    label_id = tf.argmax(label == commands)
    return mfcc_features, label_id

# %%
def preprocess_mfcc_dataset(files):
    files_ds = tf.data.Dataset.from_tensor_slices(files)
    return (
        files_ds
        .map(get_waveform_and_label,      num_parallel_calls=tf.data.AUTOTUNE)
        .map(get_mfcc_and_label_id, num_parallel_calls=tf.data.AUTOTUNE)
    )

# %%
spectrogram_mfcc_ds = preprocess_mfcc_dataset(train_files)
train_mfcc_ds = spectrogram_mfcc_ds
val_mfcc_ds = preprocess_mfcc_dataset(val_files)
test_mfcc_ds = preprocess_mfcc_dataset(test_files)

# %%
batch_size = 128

train_mfcc_ds = (
    preprocess_mfcc_dataset(train_files)
    .cache()
    .shuffle(buffer_size=len(train_files), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_mfcc_ds = (
    preprocess_mfcc_dataset(val_files)
    .batch(batch_size)
    .cache()
    .prefetch(tf.data.AUTOTUNE)
)

# %%
for mfcc, _ in spectrogram_mfcc_ds.take(1):
    input_mfcc_shape = mfcc.shape
print('Размер входных данных для MFCC:', input_mfcc_shape)

num_labels = len(commands)
print(num_labels)
# Out:
# Размер входных данных для MFCC: (98, 13, 1)
# 30

# %% [markdown]
# # Dense

# %%
model_mfcc_dense = models.Sequential([
    layers.Input(shape=(input_mfcc_shape[0] * input_mfcc_shape[1],)),
    
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.3),
    
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    
    layers.Dense(128, activation='relu'),
    layers.Dense(num_labels)
])

model_mfcc_dense.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 512)                 │         652,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 30)                  │           3,870 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 820,894 (3.13 MB)
#  Trainable params: 820,894 (3.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_mfcc_dense.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
train_ds_dense = train_mfcc_ds.map(lambda x, y: (tf.reshape(x, [-1, input_mfcc_shape[0] * input_mfcc_shape[1]]), y))
val_ds_dense = val_mfcc_ds.map(lambda x, y: (tf.reshape(x, [-1, input_mfcc_shape[0] * input_mfcc_shape[1]]), y))
test_ds_dense = test_mfcc_ds.map(lambda x, y: (tf.reshape(x, [-1, input_mfcc_shape[0] * input_mfcc_shape[1]]), y))

# %%
EPOCHS = 200
history_dense = model_mfcc_dense.fit(
    train_ds_dense,
    validation_data=val_ds_dense,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True)
)
# Out:
# Epoch 1/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 71s 19ms/step - accuracy: 0.1218 - loss: 3.6349 - val_accuracy: 0.5098 - val_loss: 1.7014
# Epoch 2/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.3718 - loss: 2.1136 - val_accuracy: 0.6702 - val_loss: 1.1792
# Epoch 3/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.4645 - loss: 1.7924 - val_accuracy: 0.6894 - val_loss: 1.0553
# Epoch 4/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.5133 - loss: 1.6171 - val_accuracy: 0.7446 - val_loss: 0.9119
# Epoch 5/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.5435 - loss: 1.5103 - val_accuracy: 0.7684 - val_loss: 0.8246
# Epoch 6/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.5736 - loss: 1.4170 - val_accuracy: 0.7617 - val_loss: 0.8243
# Epoch 7/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.5917 - loss: 1.3585 - val_accuracy: 0.7742 - val_loss: 0.7682
# Epoch 8/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.6067 - loss: 1.3012 - val_accuracy: 0.7903 - val_loss: 0.7408
# Epoch 9/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.6242 - loss: 1.2473 - val_accuracy: 0.7976 - val_loss: 0.7203
# Epoch 10/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.6285 - loss: 1.2260 - val_accuracy: 0.8010 - val_loss: 0.6868
# Epoch 11/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.6406 - loss: 1.1932 - val_accuracy: 0.7996 - val_loss: 0.6870
# Epoch 12/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.6497 - loss: 1.1580 - val_accuracy: 0.8065 - val_loss: 0.6617
# Epoch 13/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.6562 - loss: 1.1343 - val_accuracy: 0.8141 - val_loss: 0.6481
# Epoch 14/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.6653 - loss: 1.1106 - val_accuracy: 0.8209 - val_loss: 0.6328
# Epoch 15/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.6697 - loss: 1.0947 - val_accuracy: 0.8158 - val_loss: 0.6269
# Epoch 16/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.6749 - loss: 1.0803 - val_accuracy: 0.8132 - val_loss: 0.6373
# Epoch 17/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.6815 - loss: 1.0544 - val_accuracy: 0.8246 - val_loss: 0.6157
# Epoch 18/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.6872 - loss: 1.0425 - val_accuracy: 0.8268 - val_loss: 0.6059
# Epoch 19/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.6892 - loss: 1.0217 - val_accuracy: 0.8201 - val_loss: 0.6251
# Epoch 20/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.6932 - loss: 1.0182 - val_accuracy: 0.8269 - val_loss: 0.5900
# Epoch 21/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.6986 - loss: 0.9958 - val_accuracy: 0.8295 - val_loss: 0.6034
# Epoch 22/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.7022 - loss: 0.9830 - val_accuracy: 0.8314 - val_loss: 0.5853
# Epoch 23/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.7077 - loss: 0.9631 - val_accuracy: 0.8285 - val_loss: 0.6052
# Epoch 24/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.7107 - loss: 0.9603 - val_accuracy: 0.8367 - val_loss: 0.5710
# Epoch 25/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.7130 - loss: 0.9450 - val_accuracy: 0.8373 - val_loss: 0.5649
# Epoch 26/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.7156 - loss: 0.9316 - val_accuracy: 0.8387 - val_loss: 0.5715
# Epoch 27/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.7217 - loss: 0.9158 - val_accuracy: 0.8388 - val_loss: 0.5783
# Epoch 28/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 13s 16ms/step - accuracy: 0.7208 - loss: 0.9132 - val_accuracy: 0.8302 - val_loss: 0.5865
# Epoch 29/200
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.7250 - loss: 0.9080 - val_accuracy: 0.8360 - val_loss: 0.5671

# %%
metrics = history_dense.history

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history_dense.epoch, metrics['accuracy'], label='Train Accuracy')
plt.plot(history_dense.epoch, metrics['val_accuracy'], label='Val Accuracy')
plt.title('Точность по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Точность')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history_dense.epoch, metrics['loss'], label='Train Loss')
plt.plot(history_dense.epoch, metrics['val_loss'], label='Val Loss')
plt.title('Потеря по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Потеря')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("training_metrics.png", dpi=300)
plt.show()

# %%
test_mfcc_audio = []
test_mfcc_labels = []

for audio, label in test_ds_dense:
  test_mfcc_audio.append(audio.numpy())
  test_mfcc_labels.append(label.numpy())

test_mfcc_audio = np.array(test_mfcc_audio)
test_mfcc_labels = np.array(test_mfcc_labels)

test_mfcc_audio = np.squeeze(test_mfcc_audio, axis=1)

# %%
y_pred = np.argmax(model_mfcc_dense.predict(test_mfcc_audio), axis=1)
y_true = test_mfcc_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Точность на тестовом наборе: {test_acc:.0%}')
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Точность на тестовом наборе: 84%

# %%
report = classification_report(y_true, y_pred, target_names=commands, digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          cat     0.8508    0.8851    0.8676       174
#          yes     0.9456    0.9496    0.9476       238
#          one     0.8138    0.8481    0.8306       237
#          off     0.8340    0.8517    0.8428       236
#           on     0.7798    0.7173    0.7473       237
#          wow     0.9102    0.8686    0.8889       175
#         stop     0.9459    0.8824    0.9130       238
#          dog     0.7196    0.7771    0.7473       175
#         four     0.8831    0.8571    0.8699       238
#          two     0.8995    0.7899    0.8412       238
#         tree     0.8207    0.6839    0.7461       174
#        eight     0.9025    0.9025    0.9025       236
#        happy     0.9643    0.9257    0.9446       175
#         five     0.8614    0.7373    0.7945       236
#           no     0.6485    0.7983    0.7156       238
#        three     0.7370    0.8432    0.7866       236
#       marvin     0.9195    0.9143    0.9169       175
#          bed     0.7044    0.8314    0.7627       172
#        house     0.9326    0.9486    0.9405       175
#         zero     0.9440    0.9202    0.9319       238
#           go     0.6000    0.6933    0.6433       238
#        seven     0.8295    0.9202    0.8725       238
#         left     0.9423    0.8305    0.8829       236
#       sheila     0.9758    0.9253    0.9499       174
#         bird     0.8963    0.8448    0.8698       174
#         down     0.8197    0.6356    0.7160       236
#          six     0.9241    0.8734    0.8980       237
#           up     0.7704    0.8319    0.8000       238
#         nine     0.7808    0.8565    0.8169       237
#        right     0.8672    0.8819    0.8745       237
#
#     accuracy                         0.8390      6486
#    macro avg     0.8474    0.8409    0.8421      6486
# weighted avg     0.8454    0.8390    0.8401      6486

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 7))

sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g',
            cmap='Blues')
plt.xlabel('Предсказание')
plt.ylabel('Метка')
plt.savefig("conf_matrix.png", dpi=300)
plt.show()

# %% [markdown]
# # CNN

# %%
norm_layer = layers.Normalization()

norm_layer.adapt(data=spectrogram_mfcc_ds.map(map_func=lambda spec, label: spec))

# %%
model_mfcc_cnn = models.Sequential([
    layers.Input(shape=input_mfcc_shape),
    layers.Resizing(32, 32),
    norm_layer,
    
    layers.Conv2D(32, 3),
    layers.Activation('relu'),
    
    layers.Conv2D(64, 3),
    layers.Activation('relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),

    layers.Conv2D(128, 3),
    layers.Activation('relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),
    
    layers.Flatten(),
    layers.Dense(128, activation='relu'), 
    layers.Dropout(0.5),
    
    layers.Dense(num_labels),
])

model_mfcc_cnn.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resizing (Resizing)                  │ (None, 32, 32, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ normalization (Normalization)        │ (None, 32, 32, 1)           │               3 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 30, 30, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 30, 30, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 28, 28, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 28, 28, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 14, 14, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 12, 12, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 12, 12, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 6, 6, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 6, 6, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4608)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │         589,952 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 30)                  │           3,870 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 686,497 (2.62 MB)
#  Trainable params: 686,494 (2.62 MB)
#  Non-trainable params: 3 (16.00 B)

# %%
model_mfcc_cnn.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)

# %%
EPOCHS = 50
history = model_mfcc_cnn.fit(
    train_mfcc_ds,
    validation_data=val_mfcc_ds,
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(verbose=1, patience=4),
)
# Out:
# Epoch 1/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 251s 303ms/step - accuracy: 0.2342 - loss: 2.6713 - val_accuracy: 0.7843 - val_loss: 0.7877
# Epoch 2/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 246s 304ms/step - accuracy: 0.5975 - loss: 1.3610 - val_accuracy: 0.8401 - val_loss: 0.5424
# Epoch 3/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 256s 297ms/step - accuracy: 0.6679 - loss: 1.1126 - val_accuracy: 0.8586 - val_loss: 0.4688
# Epoch 4/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 239s 295ms/step - accuracy: 0.7042 - loss: 0.9907 - val_accuracy: 0.8807 - val_loss: 0.4075
# Epoch 5/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 242s 298ms/step - accuracy: 0.7295 - loss: 0.9033 - val_accuracy: 0.8932 - val_loss: 0.3760
# Epoch 6/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 239s 296ms/step - accuracy: 0.7491 - loss: 0.8467 - val_accuracy: 0.8971 - val_loss: 0.3549
# Epoch 7/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 262s 296ms/step - accuracy: 0.7580 - loss: 0.8037 - val_accuracy: 0.9013 - val_loss: 0.3395
# Epoch 8/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 237s 292ms/step - accuracy: 0.7699 - loss: 0.7612 - val_accuracy: 0.9045 - val_loss: 0.3198
# Epoch 9/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 235s 290ms/step - accuracy: 0.7755 - loss: 0.7439 - val_accuracy: 0.9062 - val_loss: 0.3133
# Epoch 10/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 261s 289ms/step - accuracy: 0.7858 - loss: 0.7099 - val_accuracy: 0.9142 - val_loss: 0.3040
# Epoch 11/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 233s 288ms/step - accuracy: 0.7902 - loss: 0.6884 - val_accuracy: 0.9101 - val_loss: 0.2974
# Epoch 12/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 260s 286ms/step - accuracy: 0.7978 - loss: 0.6607 - val_accuracy: 0.9142 - val_loss: 0.2887
# Epoch 13/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 236s 292ms/step - accuracy: 0.8035 - loss: 0.6532 - val_accuracy: 0.9183 - val_loss: 0.2872
# Epoch 14/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 231s 286ms/step - accuracy: 0.8060 - loss: 0.6391 - val_accuracy: 0.9215 - val_loss: 0.2819
# Epoch 15/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 230s 285ms/step - accuracy: 0.8124 - loss: 0.6156 - val_accuracy: 0.9190 - val_loss: 0.2854
# Epoch 16/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 230s 284ms/step - accuracy: 0.8140 - loss: 0.6119 - val_accuracy: 0.9210 - val_loss: 0.2720
# Epoch 17/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 229s 283ms/step - accuracy: 0.8185 - loss: 0.5929 - val_accuracy: 0.9212 - val_loss: 0.2696
# Epoch 18/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 233s 288ms/step - accuracy: 0.8191 - loss: 0.5897 - val_accuracy: 0.9247 - val_loss: 0.2643
# Epoch 19/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 235s 290ms/step - accuracy: 0.8205 - loss: 0.5886 - val_accuracy: 0.9247 - val_loss: 0.2638
# Epoch 20/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 234s 289ms/step - accuracy: 0.8273 - loss: 0.5604 - val_accuracy: 0.9249 - val_loss: 0.2709
# Epoch 21/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 233s 288ms/step - accuracy: 0.8279 - loss: 0.5581 - val_accuracy: 0.9247 - val_loss: 0.2623
# Epoch 22/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 233s 287ms/step - accuracy: 0.8303 - loss: 0.5555 - val_accuracy: 0.9234 - val_loss: 0.2644
# Epoch 23/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 238s 294ms/step - accuracy: 0.8324 - loss: 0.5448 - val_accuracy: 0.9238 - val_loss: 0.2708
# Epoch 24/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 237s 293ms/step - accuracy: 0.8359 - loss: 0.5343 - val_accuracy: 0.9263 - val_loss: 0.2571
# Epoch 25/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 264s 295ms/step - accuracy: 0.8362 - loss: 0.5326 - val_accuracy: 0.9258 - val_loss: 0.2539
# Epoch 26/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 232s 287ms/step - accuracy: 0.8383 - loss: 0.5239 - val_accuracy: 0.9240 - val_loss: 0.2620
# Epoch 27/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 236s 292ms/step - accuracy: 0.8404 - loss: 0.5163 - val_accuracy: 0.9298 - val_loss: 0.2495
# Epoch 28/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 234s 289ms/step - accuracy: 0.8431 - loss: 0.5126 - val_accuracy: 0.9283 - val_loss: 0.2556
# Epoch 29/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 233s 287ms/step - accuracy: 0.8435 - loss: 0.5087 - val_accuracy: 0.9284 - val_loss: 0.2484
# Epoch 30/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 260s 285ms/step - accuracy: 0.8420 - loss: 0.5101 - val_accuracy: 0.9284 - val_loss: 0.2490
# Epoch 31/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 262s 285ms/step - accuracy: 0.8467 - loss: 0.4965 - val_accuracy: 0.9281 - val_loss: 0.2598
# Epoch 32/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 263s 287ms/step - accuracy: 0.8459 - loss: 0.4942 - val_accuracy: 0.9308 - val_loss: 0.2492
# Epoch 33/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 232s 287ms/step - accuracy: 0.8481 - loss: 0.4823 - val_accuracy: 0.9278 - val_loss: 0.2496
# Epoch 33: early stopping

# %%
metrics = history.history

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.epoch, metrics['accuracy'], label='Train Accuracy')
plt.plot(history.epoch, metrics['val_accuracy'], label='Val Accuracy')
plt.title('Точность по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Точность')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.epoch, metrics['loss'], label='Train Loss')
plt.plot(history.epoch, metrics['val_loss'], label='Val Loss')
plt.title('Потеря по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Потеря')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("training_metrics.png", dpi=300)
plt.show()

# %%
test_mfcc_audio = []
test_mfcc_labels = []

for audio, label in test_mfcc_ds:
  test_mfcc_audio.append(audio.numpy())
  test_mfcc_labels.append(label.numpy())

test_mfcc_audio = np.array(test_mfcc_audio)
test_mfcc_labels = np.array(test_mfcc_labels)

# %%
y_pred = np.argmax(model_mfcc_cnn.predict(test_mfcc_audio), axis=1)
y_true = test_mfcc_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Точность на тестовом наборе: {test_acc:.0%}')
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step
# Точность на тестовом наборе: 93%

# %%
report = classification_report(y_true, y_pred, target_names=commands, digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          cat     0.9581    0.9195    0.9384       174
#          yes     0.9828    0.9580    0.9702       238
#          one     0.9458    0.9578    0.9518       237
#          off     0.8857    0.9195    0.9023       236
#           on     0.8992    0.9030    0.9011       237
#          wow     0.9282    0.9600    0.9438       175
#         stop     0.9644    0.9118    0.9374       238
#          dog     0.9349    0.9029    0.9186       175
#         four     0.9440    0.9202    0.9319       238
#          two     0.9069    0.9412    0.9237       238
#         tree     0.8763    0.9368    0.9056       174
#        eight     0.8846    0.9746    0.9274       236
#        happy     0.9884    0.9714    0.9798       175
#         five     0.9336    0.8941    0.9134       236
#           no     0.8543    0.8866    0.8701       238
#        three     0.9309    0.8559    0.8918       236
#       marvin     0.9765    0.9486    0.9623       175
#          bed     0.9321    0.8779    0.9042       172
#        house     0.9716    0.9771    0.9744       175
#         zero     0.9506    0.9706    0.9605       238
#           go     0.8701    0.8445    0.8571       238
#        seven     0.9701    0.9538    0.9619       238
#         left     0.9180    0.9492    0.9333       236
#       sheila     0.9824    0.9598    0.9709       174
#         bird     0.9708    0.9540    0.9623       174
#         down     0.8974    0.8898    0.8936       236
#          six     0.9494    0.9494    0.9494       237
#           up     0.8755    0.9454    0.9091       238
#         nine     0.9402    0.9283    0.9342       237
#        right     0.9456    0.9536    0.9496       237
#
#     accuracy                         0.9295      6486
#    macro avg     0.9323    0.9305    0.9310      6486
# weighted avg     0.9304    0.9295    0.9296      6486

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 7))

sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g',
            cmap='Blues')
plt.xlabel('Предсказание')
plt.ylabel('Метка')
plt.savefig("conf_matrix.png", dpi=300)
plt.show()

# %% [markdown]
# # TCN

# %%
def get_mfcc_and_label_id(audio, label):
    mfcc_features = get_mfcc(audio)
    mfcc_features = tf.squeeze(mfcc_features, axis=-1)
    label_id = tf.argmax(label == commands)
    return mfcc_features, label_id

# %%
mfcc_ds = preprocess_mfcc_dataset(train_files)
train_mfcc_ds = spectrogram_mfcc_ds
val_mfcc_ds = preprocess_mfcc_dataset(val_files)
test_mfcc_ds = preprocess_mfcc_dataset(test_files)

# %%
for mfcc, _ in mfcc_ds.take(1):
    input_shape = mfcc.shape
print('Размер входных данных для MFCC:', input_shape)

num_labels = len(commands)
# Out:
# Размер входных данных для MFCC: (98, 13)

# %%
norm_layer = layers.Normalization()
norm_layer.adapt(mfcc_ds.map(lambda x, y: x))

# %%
model_mfcc_tcn = models.Sequential([
    layers.Input(shape=input_shape),
    norm_layer,
    
    layers.Conv1D(64, kernel_size=3, dilation_rate=1, padding='causal', activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    
    layers.Conv1D(128, kernel_size=3, dilation_rate=2, padding='causal', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling1D(pool_size=2),
    layers.Dropout(0.4),
    
    layers.Conv1D(256, kernel_size=3, dilation_rate=4, padding='causal', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling1D(pool_size=2),
    layers.Dropout(0.5),
    
    layers.GlobalAveragePooling1D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_labels)
])

model_mfcc_tcn.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization_1 (Normalization)      │ (None, 98, 13)              │              27 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d (Conv1D)                      │ (None, 98, 64)              │           2,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 98, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 98, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 98, 128)             │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 98, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 49, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 49, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_2 (Conv1D)                    │ (None, 49, 256)             │          98,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 49, 256)             │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 24, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 24, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling1d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling1D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 30)                  │           7,710 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 201,145 (785.73 KB)
#  Trainable params: 200,222 (782.12 KB)
#  Non-trainable params: 923 (3.61 KB)

# %%
model_mfcc_tcn.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
EPOCHS = 50
history_tcn = model_mfcc_tcn.fit(
    train_mfcc_ds.batch(batch_size).cache().prefetch(1),
    validation_data=val_mfcc_ds.batch(batch_size).cache().prefetch(1),
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(patience=6, restore_best_weights=True)
)
# Out:
# Epoch 1/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 165s 195ms/step - accuracy: 0.4128 - loss: 3.2297 - val_accuracy: 0.0386 - val_loss: 3.4774
# Epoch 2/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 112s 138ms/step - accuracy: 0.2954 - loss: 2.5079 - val_accuracy: 0.0371 - val_loss: 5.7126
# Epoch 3/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 110s 136ms/step - accuracy: 0.3685 - loss: 1.8580 - val_accuracy: 0.0372 - val_loss: 9.4909
# Epoch 4/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 110s 137ms/step - accuracy: 0.4441 - loss: 1.5178 - val_accuracy: 0.0368 - val_loss: 6.2097
# Epoch 5/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 111s 138ms/step - accuracy: 0.4794 - loss: 1.3905 - val_accuracy: 0.0366 - val_loss: 10.1199
# Epoch 6/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 112s 138ms/step - accuracy: 0.4998 - loss: 1.2965 - val_accuracy: 0.0366 - val_loss: 25.6358
# Epoch 7/50
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 112s 138ms/step - accuracy: 0.4938 - loss: 1.3488 - val_accuracy: 0.0366 - val_loss: 10.5733

# %%
model_mfcc_tcn.save("mfcc_tcn.keras")

# %%
metrics = history_tcn.history

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history_tcn.epoch, metrics['accuracy'], label='Train Accuracy')
plt.plot(history_tcn.epoch, metrics['val_accuracy'], label='Val Accuracy')
plt.title('Точность по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Точность')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history_tcn.epoch, metrics['loss'], label='Train Loss')
plt.plot(history_tcn.epoch, metrics['val_loss'], label='Val Loss')
plt.title('Потеря по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Потеря')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("training_metrics_spect_tcn.png", dpi=300)
plt.show()

# %%
test_audio = []
test_labels = []

for audio, label in test_mfcc_ds:
  test_audio.append(audio.numpy()) # Преобразуем тензор в массив NumPy и добавляем в список
  test_labels.append(label.numpy()) # Аналогично преобразуем метки

# Преобразуем списки в массивы NumPy для удобной обработки
test_audio = np.array(test_audio)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model_mfcc_tcn.predict(test_audio), axis=1) # Получаем предсказания модели на тестовом наборе
y_true = test_labels # Истинные метки классов

test_acc = sum(y_pred == y_true) / len(y_true) # Вычисляем точность на тестовом наборе
print(f'Точность на тестовом наборе: {test_acc:.0%}')
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step
# Точность на тестовом наборе: 4%

# %%
report = classification_report(y_true, y_pred, target_names=commands, digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          cat     0.0277    0.1092    0.0441       174
#          yes     0.0345    0.0168    0.0226       238
#          one     0.0318    0.1139    0.0497       237
#          off     0.0359    0.5212    0.0672       236
#           on     0.0000    0.0000    0.0000       237
#          wow     0.0345    0.0229    0.0275       175
#         stop     0.1129    0.0294    0.0467       238
#          dog     0.0000    0.0000    0.0000       175
#         four     0.0577    0.0252    0.0351       238
#          two     0.0000    0.0000    0.0000       238
#         tree     0.0000    0.0000    0.0000       174
#        eight     0.0000    0.0000    0.0000       236
#        happy     0.0000    0.0000    0.0000       175
#         five     0.0000    0.0000    0.0000       236
#           no     0.0000    0.0000    0.0000       238
#        three     0.0000    0.0000    0.0000       236
#       marvin     0.0000    0.0000    0.0000       175
#          bed     0.0000    0.0000    0.0000       172
#        house     0.0000    0.0000    0.0000       175
#         zero     0.0000    0.0000    0.0000       238
#           go     0.0000    0.0000    0.0000       238
#        seven     0.0000    0.0000    0.0000       238
#         left     0.0000    0.0000    0.0000       236
#       sheila     0.0000    0.0000    0.0000       174
#         bird     0.0000    0.0000    0.0000       174
#         down     0.0000    0.0000    0.0000       236
#          six     0.0235    0.0211    0.0222       237
#           up     0.0000    0.0000    0.0000       238
#         nine     0.0454    0.1730    0.0719       237
#        right     0.0000    0.0000    0.0000       237
#
#     accuracy                         0.0364      6486
#    macro avg     0.0135    0.0344    0.0129      6486
# weighted avg     0.0142    0.0364    0.0135      6486
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 7))

sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g',
            cmap='Blues')
plt.xlabel('Предсказание')
plt.ylabel('Метка')
plt.savefig("conf_matrix_spect_tcn.png", dpi=300)
plt.show()

# %% [markdown]
# # CRNN

# %%
def get_mfcc_and_label_id(audio, label):
    mfcc_features = get_mfcc(audio)
    label_id = tf.argmax(label == commands)
    return mfcc_features, label_id

# %%
mfcc_ds = preprocess_mfcc_dataset(train_files)
train_mfcc_ds = spectrogram_mfcc_ds
val_mfcc_ds = preprocess_mfcc_dataset(val_files)
test_mfcc_ds = preprocess_mfcc_dataset(test_files)

# %%
for mfcc, _ in mfcc_ds.take(1):
    input_shape = mfcc.shape
print('Размер входных данных для MFCC:', input_shape)

num_labels = len(commands)
# Out:
# Размер входных данных для MFCC: (98, 13, 1)

# %%
norm_layer = layers.Normalization()
norm_layer.adapt(mfcc_ds.map(lambda x, y: x))

# %%
model_mfcc_crnn = models.Sequential([
    layers.Input(shape=input_shape),
    norm_layer,
    
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),
    Dropout(0.2),
    
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),
    Dropout(0.3),
    
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),
    Dropout(0.4),
    
    layers.Reshape((-1, 128)), 
    
    Bidirectional(LSTM(64, return_sequences=True)),
    Dropout(0.5),
    Bidirectional(LSTM(32)),
    Dropout(0.5),
    
    Dense(128, activation='relu'),
    Dropout(0.4),
    Dense(num_labels)
])

model_mfcc_crnn.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization_2 (Normalization)      │ (None, 98, 13, 1)           │               3 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 98, 13, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 49, 6, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 49, 6, 32)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 49, 6, 64)           │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 24, 3, 64)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 24, 3, 64)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 24, 3, 128)          │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 12, 1, 128)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 12, 1, 128)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 12, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 12, 128)             │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 12, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 64)                  │          41,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 30)                  │           3,870 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 244,897 (956.63 KB)
#  Trainable params: 244,894 (956.62 KB)
#  Non-trainable params: 3 (16.00 B)

# %%
model_mfcc_crnn.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
EPOCHS = 150
history_crnn = model_mfcc_crnn.fit(
    train_mfcc_ds.batch(batch_size).cache().prefetch(1),
    validation_data=val_mfcc_ds.batch(batch_size).cache().prefetch(1),
    epochs=EPOCHS,
    callbacks=tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
)
# Out:
# Epoch 1/150
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 219s 254ms/step - accuracy: 0.2365 - loss: 2.9638 - val_accuracy: 0.0368 - val_loss: 3.4044
# Epoch 2/150
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 214s 195ms/step - accuracy: 0.3070 - loss: 2.5978 - val_accuracy: 0.0366 - val_loss: 3.4002
# Epoch 3/150
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 158s 195ms/step - accuracy: 0.4229 - loss: 2.0070 - val_accuracy: 0.0366 - val_loss: 3.5502
# Epoch 4/150
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 202s 195ms/step - accuracy: 0.4363 - loss: 1.7982 - val_accuracy: 0.0366 - val_loss: 4.7562
# Epoch 5/150
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 204s 197ms/step - accuracy: 0.4842 - loss: 1.5526 - val_accuracy: 0.0366 - val_loss: 7.6077
# Epoch 6/150
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 159s 196ms/step - accuracy: 0.4629 - loss: 1.5299 - val_accuracy: 0.0366 - val_loss: 8.2597
# Epoch 7/150
# 809/809 ━━━━━━━━━━━━━━━━━━━━ 156s 193ms/step - accuracy: 0.5006 - loss: 1.4327 - val_accuracy: 0.0366 - val_loss: 9.7836

# %%
model_mfcc_crnn.save("mfcc_crnn.keras")

# %%
metrics = history_crnn.history

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history_crnn.epoch, metrics['accuracy'], label='Train Accuracy')
plt.plot(history_crnn.epoch, metrics['val_accuracy'], label='Val Accuracy')
plt.title('Точность по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Точность')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history_crnn.epoch, metrics['loss'], label='Train Loss')
plt.plot(history_crnn.epoch, metrics['val_loss'], label='Val Loss')
plt.title('Потеря по эпохам')
plt.xlabel('Эпоха')
plt.ylabel('Потеря')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("training_metrics_spect_tcn.png", dpi=300)
plt.show()

# %%
test_audio = []
test_labels = []

for audio, label in test_mfcc_ds:
  test_audio.append(audio.numpy())
  test_labels.append(label.numpy())

test_audio = np.array(test_audio)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model_mfcc_crnn.predict(test_audio), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Точность на тестовом наборе: {test_acc:.0%}')
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step
# Точность на тестовом наборе: 4%

# %%
report = classification_report(y_true, y_pred, target_names=commands, digits=4)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          cat     0.0000    0.0000    0.0000       174
#          yes     0.0000    0.0000    0.0000       238
#          one     0.0365    1.0000    0.0705       237
#          off     0.0000    0.0000    0.0000       236
#           on     0.0000    0.0000    0.0000       237
#          wow     0.0000    0.0000    0.0000       175
#         stop     0.0000    0.0000    0.0000       238
#          dog     0.0000    0.0000    0.0000       175
#         four     0.0000    0.0000    0.0000       238
#          two     0.0000    0.0000    0.0000       238
#         tree     0.0000    0.0000    0.0000       174
#        eight     0.0000    0.0000    0.0000       236
#        happy     0.0000    0.0000    0.0000       175
#         five     0.0000    0.0000    0.0000       236
#           no     0.0000    0.0000    0.0000       238
#        three     0.0000    0.0000    0.0000       236
#       marvin     0.0000    0.0000    0.0000       175
#          bed     0.0000    0.0000    0.0000       172
#        house     0.0000    0.0000    0.0000       175
#         zero     0.0000    0.0000    0.0000       238
#           go     0.0000    0.0000    0.0000       238
#        seven     0.0000    0.0000    0.0000       238
#         left     0.0000    0.0000    0.0000       236
#       sheila     0.0000    0.0000    0.0000       174
#         bird     0.0000    0.0000    0.0000       174
#         down     0.0000    0.0000    0.0000       236
#          six     0.0000    0.0000    0.0000       237
#           up     0.0000    0.0000    0.0000       238
#         nine     0.0000    0.0000    0.0000       237
#        right     0.0000    0.0000    0.0000       237
#
#     accuracy                         0.0365      6486
#    macro avg     0.0012    0.0333    0.0024      6486
# weighted avg     0.0013    0.0365    0.0026      6486
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 7))

sns.heatmap(confusion_mtx,
            xticklabels=commands,
            yticklabels=commands,
            annot=True, fmt='g',
            cmap='Blues')
plt.xlabel('Предсказание')
plt.ylabel('Метка')
plt.savefig("conf_matrix_spect_crnn.png", dpi=300)
plt.show()
